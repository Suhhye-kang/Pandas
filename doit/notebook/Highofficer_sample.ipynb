# %%
import pandas as pd

# %%
import chardet

# %%
import urllib.request

# %%
import chardet

with open('C:\\Github\\Pandas\\doit\\data\\highofficer_2018-2019.csv', 'rt') as f:
    lines  = f.readlines()

# %%
f
# Out:
# <_io.TextIOWrapper name='C:\\Github\\Pandas\\doit\\data\\highofficer_2018-2019.csv' mode='rt' encoding='cp949'>

# %%
df=pd.read_csv('C:\\Github\\Pandas\\doit\\data\\highofficer_2018-2019.csv',encoding='cp949')

# %%
df
# Out:
#        Unnamed: 0 소속_대분류 소속_소분류     소속      직위   성명           개별index  \
# 0               1    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 1               2    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 2               3    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 3               4    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 4               5    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# ...           ...    ...    ...    ...     ...  ...               ...
# 86169       86170    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86170       86171    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86171       86172    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86172       86173    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86173       86174    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
#
#                대분류 본인과의 관계  재산의 종류             소재지 면적 등 권리의 명세     종전가액  증가액  \
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'original_ID'})

# %%
df
# Out:
#        original_ID 소속_대분류 소속_소분류     소속      직위   성명           개별index  \
# 0                1    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 1                2    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 2                3    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 3                4    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# 4                5    청와대    청와대    대통령     대통령  문재인       대통령-대통령-문재인
# ...            ...    ...    ...    ...     ...  ...               ...
# 86169        86170    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86170        86171    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86171        86172    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86172        86173    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
# 86173        86174    사법부    사법부  헌법재판소  기획조정실장  김용호  헌법재판소-기획조정실장-김용호
#
#                대분류 본인과의 관계  재산의 종류             소재지 면적 등 권리의 명세     종전가액  증가액  \
# ...

# %%
df.groupby("소속_대분류").nunique()
# Out:
#         original_ID  소속_대분류  소속_소분류   소속   직위    성명  개별index  대분류  본인과의 관계  \
# 소속_대분류
# 국회            13298       1       5   27   23   362      388   17       20
# 사법부            6036       1       1   43   37   203      272   16       13
# 정부            21385       1      41  457  207   950     1093   17       22
# 지자체           43954       1       1  293   40  1813     1931   17       28
# 청와대            1501       1       1    4   68    73       80   14       17
#
#         재산의 종류  소재지 면적 등 권리의 명세   종전가액    증가액  증가액_실거래가    감소액  감소액_실거래가  \
# 소속_대분류
# 국회          70             9176   7842   5106       287   3905       182
# 사법부         67             4281   3954   2667        66   1732        82
# 정부          89            16935  12038   7632       489   6285       318
# 지자체        104            36060  23368  12496       819  10439       560
# 청와대         48             1226   1021    608        18    572        32
#
#          현재가액  변동사유  years
# 소속_대분류
# ...

# %%
df.groupby("소속_소분류").nunique()
# Out:
#                                   original_ID  소속_대분류  소속_소분류   소속  직위    성명  \
# 소속_소분류
# 가습기살균제사건과4<U+2024>16세월호참사특별조사위원회           91       1       1    1   3     5
# 감사원                                       352       1       1    2   8    15
# 고용노동부                                     403       1       1   12  11    20
# 공정거래위원회                                   178       1       1    2   5     7
# 과학기술정보통신부                                1269       1       1   41  15    55
# 관세청                                       214       1       1    8   3    12
# 교육부                                      2548       1       1   56  23   101
# 국가보훈처                                      85       1       1    4   6     6
# 국가인권위원회                                   148       1       1    1   3     7
# 국가정보원                                     173       1       1    1   5     6
# 국무총리실                                     581       1       1   10  17    26
# ...
