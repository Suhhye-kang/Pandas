# %%
import pandas as pd

# %%
all1=pd.read_excel('/Users/kang/Pandas/Real/all_2010_2013.xlsx')

# %%
all2=pd.read_excel('/Users/kang/Pandas/Real/all_2014_2016.xlsx')

# %%
all3=pd.read_excel('/Users/kang/Pandas/Real/all_2017_2020.xlsx')

# %%
rent1=pd.read_excel('/Users/kang/Pandas/Real/apt_rent_all_new_1.xlsx')

# %%
rent2=pd.read_excel('/Users/kang/Pandas/Real/apt_rent_all_new_2.xlsx')

# %%
rent=pd.concat([rent1,rent2])

# %%
sell=pd.read_excel('/Users/kang/Pandas/Real/apt_sell_all.xlsx')

# %%
rent
# Out:
#         Unnamed: 0   city town village            name category   size  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 2                2  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 3                8  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  67.28
# 4                9  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  79.97
# ...            ...    ...  ...     ...             ...      ...    ...
# 912962      168534  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912963      168535  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912964      168536  서울특별시  중랑구     중화동         한영(101)       전세  71.83
# 912965      168538  서울특별시  중랑구     중화동         한영(103)       월세  50.29
# 912966      168540  서울특별시  중랑구     중화동         한영(104)       전세  67.57
#
#         deposit  monthlyrent  floor  year_built    yy  mm  dd zipcode  \
# ...

# %%
sell
# Out:
#         Unnamed: 0   city town village            name  size  price_sold  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      160000
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      149500
# 2                2  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      155000
# 3                3  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      157000
# 4                4  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      151500
# ...            ...    ...  ...     ...             ...   ...         ...
# 815967       57229  서울특별시  중랑구     중화동             한신2    84       35700
# 815968       57230  서울특별시  중랑구     중화동             한신2    84       35800
# 815969       57231  서울특별시  중랑구     중화동         한영(104)    68       23250
# 815970       57232  서울특별시  중랑구     중화동           현대휴앤미    82       28000
# 815971       57233  서울특별시  중랑구     중화동           현대휴앤미   100       32500
#
#         floor  year_built    yy  mm  dd zipcode      address
# ...

# %%
all=pd.concat([all1,all2,all3])

# %%
del all['Unnamed: 0']

# %%
all
# Out:
#        type   city town village            name category    size  price_sold  \
# 0       아파트  서울특별시  강남구     개포동  개포2차현대아파트(220)       매매   77.00       57000
# 1       아파트  서울특별시  강남구     개포동  개포2차현대아파트(220)       매매   77.00       57000
# 2       아파트  서울특별시  강남구     개포동          개포우성3차       매매  104.00       71000
# 3       아파트  서울특별시  강남구     개포동          개포우성3차       매매  161.00      108500
# 4       아파트  서울특별시  강남구     개포동          개포우성3차       매매  104.00       65000
# ...     ...    ...  ...     ...             ...      ...     ...         ...
# 955019  아파트  서울특별시  중랑구     중화동             한신2       월세   59.76           0
# 955020  아파트  서울특별시  중랑구     중화동             한신2       전세   59.76           0
# 955021  아파트  서울특별시  중랑구     중화동             한신2       전세   59.76           0
# 955022  아파트  서울특별시  중랑구     중화동             한신2       전세   59.76           0
# 955023  아파트  서울특별시  중랑구     중화동           현대휴앤미       전세   82.97           0
#
# ...

# %%
all['age']=2020-all['year_built']

# %%
rent1=rent.loc[rent['monthlyrent']==0]

# %%
rent1=rent.loc[rent['category']=='전세']

# %%
rent1
# Out:
#         Unnamed: 0   city town village            name category   size  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 2                2  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 3                8  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  67.28
# 4                9  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  79.97
# ...            ...    ...  ...     ...             ...      ...    ...
# 912961      168533  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912962      168534  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912963      168535  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912964      168536  서울특별시  중랑구     중화동         한영(101)       전세  71.83
# 912966      168540  서울특별시  중랑구     중화동         한영(104)       전세  67.57
#
#         deposit  monthlyrent  floor  year_built    yy  mm  dd zipcode  \
# ...

# %%
sell=all.loc[all['category']=='매매']

# %%
sell=.groupby(['yy','mm','name','size','floor','age'])['price_sold'].mean()

# %%
sell=sell.reset_index()

# %%
sell
# Out:
#            yy  mm           name  size  floor   age  price_sold
# 0        2010   8   \t(104-10)\t  30.0   11.0  26.0      6450.0
# 1        2010   8  \t(1061-18)\t  28.0    7.0  15.0     16500.0
# 2        2010   8  \t(1132-59)\t  34.0    1.0  30.0      6500.0
# 3        2010   8     \t(12-1)\t  43.0    7.0  29.0      9800.0
# 4        2010   8    \t(134-1)\t  26.0    7.0  19.0      7500.0
# ...       ...  ..            ...   ...    ...   ...         ...
# 2059869  2020   7      힐스테이트에코마곡  24.0   12.0   4.0     21000.0
# 2059870  2020   7      힐스테이트에코문정  20.0    6.0   2.0     23000.0
# 2059871  2020   7      힐스테이트에코송파  21.0   11.0   3.0     19300.0
# 2059872  2020   7          힐탑프라자  20.0   11.0  26.0      8900.0
# 2059873  2020   7          힐탑프라자  20.0   16.0  26.0      8850.0
#
# [2059874 rows x 7 columns]

# %%
sell.loc[sell['price_sold']==0]
# Out:
#            yy  mm           name    size  floor   age  price_sold
# 25775    2011   1        (1-102)   59.97    2.0  23.0         0.0
# 25776    2011   1      (1617-21)  119.02    1.0  13.0         0.0
# 25777    2011   1       (372-66)   63.90    4.0  10.0         0.0
# 25780    2011   1  (633-22)로얄팰리스   95.73    4.0  17.0         0.0
# 25781    2011   1     (717-20)한성   43.28    3.0  19.0         0.0
# ...       ...  ..            ...     ...    ...   ...         ...
# 2059863  2020   7      힐스테이트송파위례  101.80   23.0   4.0         0.0
# 2059864  2020   7      힐스테이트송파위례  101.80   26.0   4.0         0.0
# 2059865  2020   7      힐스테이트송파위례  101.80   27.0   4.0         0.0
# 2059866  2020   7      힐스테이트송파위례  101.95   12.0   4.0         0.0
# 2059867  2020   7      힐스테이트송파위례  101.95   25.0   4.0         0.0
#
# [1214223 rows x 7 columns]

# %%
rent2=rent1.groupby(['yy','mm','name','size','floor','age'])['deposit'].mean()

# %%
rent2=rent2.reset_index()

# %%
rent2
# Out:
#           yy  mm           name    size  floor  age  deposit
# 0       2011   1        (1-102)   59.97    2.0   23   3500.0
# 1       2011   1  (633-22)로얄팰리스   95.73    4.0   17  32000.0
# 2       2011   1     (717-20)한성   43.28    3.0   19   9000.0
# 3       2011   1       (739-18)   33.64    5.0   22   7000.0
# 4       2011   1       (740-25)   59.91    4.0   23  12000.0
# ...      ...  ..            ...     ...    ...  ...      ...
# 899549  2020   7      힐스테이트송파위례  101.80   16.0    4  74000.0
# 899550  2020   7      힐스테이트송파위례  101.80   23.0    4  67000.0
# 899551  2020   7      힐스테이트송파위례  101.80   27.0    4  77000.0
# 899552  2020   7      힐스테이트송파위례  101.95   12.0    4  75000.0
# 899553  2020   7      힐스테이트송파위례  101.95   25.0    4  71500.0
#
# [899554 rows x 7 columns]

# %%
df=sell.merge(rent2,how='left',left_on=['yy','mm','name','floor','size','age'],right_on=['yy','mm','name','floor','size','age'])

# %%
df
# Out:
#            yy  mm           name  size  floor   age  price_sold  deposit
# 0        2010   8   \t(104-10)\t  30.0   11.0  26.0      6450.0      NaN
# 1        2010   8  \t(1061-18)\t  28.0    7.0  15.0     16500.0      NaN
# 2        2010   8  \t(1132-59)\t  34.0    1.0  30.0      6500.0      NaN
# 3        2010   8     \t(12-1)\t  43.0    7.0  29.0      9800.0      NaN
# 4        2010   8    \t(134-1)\t  26.0    7.0  19.0      7500.0      NaN
# ...       ...  ..            ...   ...    ...   ...         ...      ...
# 2059869  2020   7      힐스테이트에코마곡  24.0   12.0   4.0     21000.0      NaN
# 2059870  2020   7      힐스테이트에코문정  20.0    6.0   2.0     23000.0      NaN
# 2059871  2020   7      힐스테이트에코송파  21.0   11.0   3.0     19300.0      NaN
# 2059872  2020   7          힐탑프라자  20.0   11.0  26.0      8900.0      NaN
# 2059873  2020   7          힐탑프라자  20.0   16.0  26.0      8850.0      NaN
#
# [2059874 rows x 8 columns]

# %%
df.loc[df['price_sold']==0]
# Out:
#            yy  mm           name    size  floor   age  price_sold  deposit  \
# 25775    2011   1        (1-102)   59.97    2.0  23.0         0.0   3500.0
# 25776    2011   1      (1617-21)  119.02    1.0  13.0         0.0      0.0
# 25777    2011   1       (372-66)   63.90    4.0  10.0         0.0      0.0
# 25780    2011   1  (633-22)로얄팰리스   95.73    4.0  17.0         0.0  32000.0
# 25781    2011   1     (717-20)한성   43.28    3.0  19.0         0.0   9000.0
# ...       ...  ..            ...     ...    ...   ...         ...      ...
# 2059863  2020   7      힐스테이트송파위례  101.80   23.0   4.0         0.0  67000.0
# 2059864  2020   7      힐스테이트송파위례  101.80   26.0   4.0         0.0      0.0
# 2059865  2020   7      힐스테이트송파위례  101.80   27.0   4.0         0.0  77000.0
# 2059866  2020   7      힐스테이트송파위례  101.95   12.0   4.0         0.0  75000.0
# 2059867  2020   7      힐스테이트송파위례  101.95   25.0   4.0         0.0  71500.0
#
#              gap
# 25775    -3500.0
# 25776        0.0
# ...

# %%
df['deposit'].fillna(0,inplace=True)

# %%
df['gap']=df['price_sold']-df['deposit']

# %%
df
# Out:
#            yy  mm           name  size  floor   age  price_sold  deposit  \
# 0        2010   8   \t(104-10)\t  30.0   11.0  26.0      6450.0      0.0
# 1        2010   8  \t(1061-18)\t  28.0    7.0  15.0     16500.0      0.0
# 2        2010   8  \t(1132-59)\t  34.0    1.0  30.0      6500.0      0.0
# 3        2010   8     \t(12-1)\t  43.0    7.0  29.0      9800.0      0.0
# 4        2010   8    \t(134-1)\t  26.0    7.0  19.0      7500.0      0.0
# ...       ...  ..            ...   ...    ...   ...         ...      ...
# 2059869  2020   7      힐스테이트에코마곡  24.0   12.0   4.0     21000.0      0.0
# 2059870  2020   7      힐스테이트에코문정  20.0    6.0   2.0     23000.0      0.0
# 2059871  2020   7      힐스테이트에코송파  21.0   11.0   3.0     19300.0      0.0
# 2059872  2020   7          힐탑프라자  20.0   11.0  26.0      8900.0      0.0
# 2059873  2020   7          힐탑프라자  20.0   16.0  26.0      8850.0      0.0
#
#              gap
# 0         6450.0
# 1        16500.0
# 2         6500.0
# 3         9800.0
# ...

# %%
df1=df.loc[(df['deposit']>0)&(df['price_sold']>0)&(df['gap']>0)]

# %%
df1
# Out:
#            yy  mm     name   size  floor   age     price_sold       deposit  \
# 27277    2011   1     고덕시영   43.0    1.0  36.0    7571.428571   5650.000000
# 27278    2011   1     고덕시영   43.0    2.0  36.0   10580.000000   7000.000000
# 27279    2011   1     고덕시영   43.0    4.0  36.0   31800.000000   6500.000000
# 47819    2011   2     고덕시영   43.0    1.0  36.0   17666.666667   4500.000000
# 67700    2011   3     고덕시영   43.0    2.0  36.0    8583.333333   5333.333333
# ...       ...  ..      ...    ...    ...   ...            ...           ...
# 2028422  2020   6  삼익대청아파트   60.0    8.0  28.0   94000.000000  50000.000000
# 2034538  2020   6  우장산롯데캐슬   85.0    4.0  17.0   56666.666667  51000.000000
# 2034681  2020   6      워커힐  196.0    5.0  42.0  102500.000000  90000.000000
# 2052485  2020   7    신대방경남   56.0    5.0  17.0   34500.000000  30500.000000
# 2059310  2020   7     현대백조   31.0    7.0  23.0   25000.000000  12000.000000
#
#                   gap
# 27277     1921.428571
# ...

# %%
df1.to_excel('/Users/kang/Pandas/Real/gap.xlsx')
