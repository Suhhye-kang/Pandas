# %%
import pandas as pd

# %%
all1=pd.read_excel('/Users/kang/Pandas/Real/all_2010_2013.xlsx')

# %%
all2=pd.read_excel('/Users/kang/Pandas/Real/all_2014_2016.xlsx')

# %%
all3=pd.read_excel('/Users/kang/Pandas/Real/all_2017_2020.xlsx')

# %%
all=pd.concat([all1,all2,all3])

# %%
all
# Out:
#         Unnamed: 0 type   city town village            name category    size  \
# 0           583253  아파트  서울특별시  강남구     개포동  개포2차현대아파트(220)       매매   77.00
# 1           583254  아파트  서울특별시  강남구     개포동  개포2차현대아파트(220)       매매   77.00
# 2           583258  아파트  서울특별시  강남구     개포동          개포우성3차       매매  104.00
# 3           583259  아파트  서울특별시  강남구     개포동          개포우성3차       매매  161.00
# 4           583260  아파트  서울특별시  강남구     개포동          개포우성3차       매매  104.00
# ...            ...  ...    ...  ...     ...             ...      ...     ...
# 955019      668451  아파트  서울특별시  중랑구     중화동             한신2       월세   59.76
# 955020      668452  아파트  서울특별시  중랑구     중화동             한신2       전세   59.76
# 955021      668453  아파트  서울특별시  중랑구     중화동             한신2       전세   59.76
# 955022      668454  아파트  서울특별시  중랑구     중화동             한신2       전세   59.76
# 955023      668456  아파트  서울특별시  중랑구     중화동           현대휴앤미       전세   82.97
#
#         price_sold  deposit  monthlyrent  floor  year_built    yy  mm  dd  \
# 0            57000        0            0    2.0      1988.0  2013   9   8
# 1            57000        0            0    2.0      1988.0  2013  12  16
# 2            71000        0            0   12.0      1984.0  2013   8  12
# 3           108500        0            0    5.0      1984.0  2013  10   8
# 4            65000        0            0    1.0      1984.0  2013  11  26
# ...            ...      ...          ...    ...         ...   ...  ..  ..
# 955019           0       50           50    4.0      1998.0  2017   4   7
# 955020           0        0            0   13.0      1998.0  2017   4  25
# 955021           0        0            0    7.0      1998.0  2017   5  10
# 955022           0        0            0   13.0      1998.0  2017   7   7
# 955023           0        0            0    7.0      2007.0  2017   2  17
#
#        zipcode      address
# 0        655-2      언주로 103
# 1        655-2      언주로 103
# 2          652      개포로 307
# 3          652      개포로 307
# 4          652      개포로 307
# ...        ...          ...
# 955019     450      동일로 752
# 955020     450      동일로 752
# 955021     450      동일로 752
# 955022     450      동일로 752
# 955023      11  봉화산로27가길 23
#
# [2401078 rows x 18 columns]

# %%
yongsan=all.loc[all['town']=='용산']

# %%
yongsan.groupby(['type','village','yy','mm'])['price_sold']
