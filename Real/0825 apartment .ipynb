# %%
import pandas as pd

# %%
rent1=pd.read_excel('/Users/kang/Pandas/Real/apt_rent_all_new_1.xlsx')

# %%
rent2=pd.read_excel('/Users/kang/Pandas/Real/apt_rent_all_new_2.xlsx')

# %%
rent=pd.concat([rent1,rent2])

# %%
sell=pd.read_excel('/Users/kang/Pandas/Real/apt_sell_all.xlsx')

# %%
rent
# Out:
#         Unnamed: 0   city town village            name category   size  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 2                2  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 3                8  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  67.28
# 4                9  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  79.97
# ...            ...    ...  ...     ...             ...      ...    ...
# 912962      168534  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912963      168535  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912964      168536  서울특별시  중랑구     중화동         한영(101)       전세  71.83
# 912965      168538  서울특별시  중랑구     중화동         한영(103)       월세  50.29
# 912966      168540  서울특별시  중랑구     중화동         한영(104)       전세  67.57
#
#         deposit  monthlyrent  floor  year_built    yy  mm  dd zipcode  \
# 0         39000            0    8.0        1988  2014   9   1   655-2
# 1         39000            0    4.0        1988  2014  12  21   655-2
# 2         43000            0    7.0        1988  2014  12  24   655-2
# 3         25000            0    5.0        1987  2014   8   8   658-1
# 4         35000            0    3.0        1987  2014   8  18   658-1
# ...         ...          ...    ...         ...   ...  ..  ..     ...
# 912962    23500            0    4.0        1998  2015   6  26     450
# 912963    27000            0   22.0        1998  2015   7  30     450
# 912964    19000            0    2.0        2003  2015   4  29  274-51
# 912965     4000           50    5.0        2003  2015   3   6  274-76
# 912966    17500            0    4.0        2003  2015   3  28  274-77
#
#            address  age
# 0          언주로 103   32
# 1          언주로 103   32
# 2          언주로 103   32
# 3            언주로 3   33
# 4            언주로 3   33
# ...            ...  ...
# 912962     동일로 752   22
# 912963     동일로 752   22
# 912964  동일로144길 74   17
# 912965  동일로144길 74   17
# 912966  동일로144길 74   17
#
# [1478880 rows x 17 columns]

# %%
sell
# Out:
#         Unnamed: 0   city town village            name  size  price_sold  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      160000
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      149500
# 2                2  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      155000
# 3                3  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      157000
# 4                4  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      151500
# ...            ...    ...  ...     ...             ...   ...         ...
# 815967       57229  서울특별시  중랑구     중화동             한신2    84       35700
# 815968       57230  서울특별시  중랑구     중화동             한신2    84       35800
# 815969       57231  서울특별시  중랑구     중화동         한영(104)    68       23250
# 815970       57232  서울특별시  중랑구     중화동           현대휴앤미    82       28000
# 815971       57233  서울특별시  중랑구     중화동           현대휴앤미   100       32500
#
#         floor  year_built    yy  mm  dd zipcode      address
# 0           2        1988  2019  11  18   655-2      언주로 103
# 1           4        1988  2020   6  23   655-2      언주로 103
# 2           4        1987  2019   8  28   658-1        언주로 3
# 3           2        1987  2019   9   2   658-1        언주로 3
# 4           5        1987  2019   9  10   658-1        언주로 3
# ...       ...         ...   ...  ..  ..     ...          ...
# 815967      3        1998  2010  12  30     450      동일로 752
# 815968      3        1998  2011   2  28     450      동일로 752
# 815969      3        2003  2011   7  12  274-77   동일로144길 74
# 815970      7        2007  2011   1  27      11  봉화산로27가길 23
# 815971      5        2007  2011   5   3      11  봉화산로27가길 23
#
# [815972 rows x 14 columns]

# %%
def quarter(x):
    if 0<x<4:
        return '1Q'
    elif 3<x<7:
        return '2Q'
    elif 6<x<10:
        return '3Q'
    else:
        return '4Q'

# %%
sell['quarter']=sell['mm'].apply(quarter)

# %%
df['size_range']=pd.cut(df['size'],[0, 66, 7199, 132, 10000], labels=['20-','20-30','30-40','40+'], duplicates='raise')

# %%
sell['age'].max()
# Out:
# 59

# %%
sell['age_range']=pd.cut(sell['age'],[0,5,10,15,20,25,30,35,40,45,50,55,60,65],include_lowest=True,labels=['-5','-10','-15','-20','-25','-30','-35','-40','-45','-50','-55','-60','-65'],duplicates='raise')

# %%
sell
# Out:
#         Unnamed: 0   city town village            name  size  price_sold  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      160000
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      149500
# 2                2  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      155000
# 3                3  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      157000
# 4                4  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      151500
# ...            ...    ...  ...     ...             ...   ...         ...
# 815967       57229  서울특별시  중랑구     중화동             한신2    84       35700
# 815968       57230  서울특별시  중랑구     중화동             한신2    84       35800
# 815969       57231  서울특별시  중랑구     중화동         한영(104)    68       23250
# 815970       57232  서울특별시  중랑구     중화동           현대휴앤미    82       28000
# 815971       57233  서울특별시  중랑구     중화동           현대휴앤미   100       32500
#
#         floor  year_built    yy  mm  dd zipcode      address quarter  age  \
# 0           2        1988  2019  11  18   655-2      언주로 103      4Q   32
# 1           4        1988  2020   6  23   655-2      언주로 103      2Q   32
# 2           4        1987  2019   8  28   658-1        언주로 3      3Q   33
# 3           2        1987  2019   9   2   658-1        언주로 3      3Q   33
# 4           5        1987  2019   9  10   658-1        언주로 3      3Q   33
# ...       ...         ...   ...  ..  ..     ...          ...     ...  ...
# 815967      3        1998  2010  12  30     450      동일로 752      4Q   22
# 815968      3        1998  2011   2  28     450      동일로 752      1Q   22
# 815969      3        2003  2011   7  12  274-77   동일로144길 74      3Q   17
# 815970      7        2007  2011   1  27      11  봉화산로27가길 23      1Q   13
# 815971      5        2007  2011   5   3      11  봉화산로27가길 23      2Q   13
#
#        age_range
# 0            -35
# 1            -35
# 2            -35
# 3            -35
# 4            -35
# ...          ...
# 815967       -25
# 815968       -25
# 815969       -20
# 815970       -15
# 815971       -15
#
# [815972 rows x 17 columns]

# %%
def my_mean_diff(values, diff_value):
    n=len(values)
    sum=0
    for value in values:
        sum+=value
    mean=sum/n
    return mean-diff_value

# %%
def rank(values,diff_value):
    n=len(values)
    sum=0
    for value in values:
        sum+

# %%
sell['rank']=pd.cut(sell['price_sold'],[q1,q2,q3,q4,q5], labels=['1','2','3','4','5'], duplicates='raise')
# Out:
# /Users/kang/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py:254: RuntimeWarning: invalid value encountered in less
#   if (np.diff(bins.astype("float64")) < 0).any():
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-051e3674024a> in <module>
# ----> 1 sell['rank']=pd.cut(sell['price_sold'],[q1,q2,q3,q4,q5], labels=['1','2','3','4','5'], duplicates='raise')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     253         # GH 26045: cast to float64 to avoid an overflow
#     254         if (np.diff(bins.astype("float64")) < 0).any():
# --> 255             raise ValueError("bins must increase monotonically.")
#     256
#     257     fac, bins = _bins_to_cuts(
#
# ValueError: bins must increase monotonically.

# %%
grouped=sell.groupby('age_range')

# %%
q1=grouped['price_sold'].quantile(0.2)
q2=grouped['price_sold'].quantile(0.4)
q3=grouped['price_sold'].quantile(0.6)
q4=grouped['price_sold'].quantile(0.8)
q5=grouped['price_sold'].quantile(1)

# %%
q3
# Out:
# age_range
# -5      84600.0
# -10     64000.0
# -15     61700.0
# -20     49000.0
# -25     43250.0
# -30     40300.0
# -35     42000.0
# -40     75500.0
# -45    115000.0
# -50     79500.0
# -55     23750.0
# -60     17000.0
# -65         NaN
# Name: price_sold, dtype: float64

# %%
for sex_group in grouped:
    print('the type is: {}\n'.format(type(sex_group)))
    print('the length is: {}\n'.format(len(sex_group)))

    first_element = sex_group[0] 
    print('the first element is: {}\n'.format(first_element))
    print('it has a type of: {}\n'.format(type(sex_group[0])))

    second_element = sex_group[1] 
    print('the second element is:\n{}\n'.format(second_element))
    print('it has a type of: {}\n'.format(type(second_element)))

    print('what we have:') 
    print(sex_group)

    break

# %%
def rank(values, diff_value):
    n=len(values)
    sum=0
    for value in values:
        sum+=value
    mean=sum/n
    return mean-diff_value

# %%
sell['rank'].nunique()
# Out:
# 1

# %%
sell['rank']=pd.qcut(sell['price_sold'],5,labels=["1","2","3","4","5"],duplicates='raise')

# %%
sell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815972 entries, 0 to 815971
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  815972 non-null  int64
#  1   city        815972 non-null  object
#  2   town        815972 non-null  object
#  3   village     815972 non-null  object
#  4   name        815972 non-null  object
#  5   size        815972 non-null  int64
#  6   price_sold  815972 non-null  int64
#  7   floor       815972 non-null  int64
#  8   year_built  815972 non-null  int64
#  9   yy          815972 non-null  int64
#  10  mm          815972 non-null  int64
#  11  dd          815972 non-null  int64
#  12  zipcode     815757 non-null  object
#  13  address     815972 non-null  object
#  14  quarter     815972 non-null  object
#  15  age         815972 non-null  int64
#  16  age_range   815972 non-null  category
#  17  rank        815972 non-null  category
# dtypes: category(2), int64(9), object(7)
# memory usage: 101.2+ MB

# %%
sell['age']=2020-sell['year_built']

# %%
rent['quarter']=sell['mm'].apply(quarter)

# %%
rent1=rent.loc[rent['monthlyrent']==0]

# %%
rent1=rent.loc[rent['category']=='전세']

# %%
rent1
# Out:
#         Unnamed: 0   city town village            name category   size  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 2                2  서울특별시  강남구     개포동  개포2차현대아파트(220)       전세  77.75
# 3                8  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  67.28
# 4                9  서울특별시  강남구     개포동  개포6차우성아파트1동~8동       전세  79.97
# ...            ...    ...  ...     ...             ...      ...    ...
# 912961      168533  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912962      168534  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912963      168535  서울특별시  중랑구     중화동             한신2       전세  59.76
# 912964      168536  서울특별시  중랑구     중화동         한영(101)       전세  71.83
# 912966      168540  서울특별시  중랑구     중화동         한영(104)       전세  67.57
#
#         deposit  monthlyrent  floor  year_built    yy  mm  dd zipcode  \
# 0         39000            0    8.0        1988  2014   9   1   655-2
# 1         39000            0    4.0        1988  2014  12  21   655-2
# 2         43000            0    7.0        1988  2014  12  24   655-2
# 3         25000            0    5.0        1987  2014   8   8   658-1
# 4         35000            0    3.0        1987  2014   8  18   658-1
# ...         ...          ...    ...         ...   ...  ..  ..     ...
# 912961    24000            0    4.0        1998  2015   6  17     450
# 912962    23500            0    4.0        1998  2015   6  26     450
# 912963    27000            0   22.0        1998  2015   7  30     450
# 912964    19000            0    2.0        2003  2015   4  29  274-51
# 912966    17500            0    4.0        2003  2015   3  28  274-77
#
#            address  age quarter
# 0          언주로 103   32      4Q
# 1          언주로 103   32      2Q
# 2          언주로 103   32      3Q
# 3            언주로 3   33      3Q
# 4            언주로 3   33      3Q
# ...            ...  ...     ...
# 912961     동일로 752   22     NaN
# 912962     동일로 752   22     NaN
# 912963     동일로 752   22     NaN
# 912964  동일로144길 74   17     NaN
# 912966  동일로144길 74   17     NaN
#
# [1070845 rows x 18 columns]

# %%
sell_q=sell.groupby(['yy','quarter','name','size','age','town','village'])['price_sold'].mean()

# %%
sell_q=sell_q.reset_index()

# %%
sell_q
# Out:
#           yy quarter          name  size  age  town village     price_sold
# 0       2010      3Q      (740-24)    34   20   구로구     구로동    9900.000000
# 1       2010      3Q      (770-40)    46   24   구로구     구로동   13100.000000
# 2       2010      3Q       (779-8)    84   14   광진구     자양동   43000.000000
# 3       2010      3Q  (791-21)태영빌라    31   21   구로구     구로동   10500.000000
# 4       2010      3Q      (792-11)    59   24   구로구     구로동   16000.000000
# ...      ...     ...           ...   ...  ...   ...     ...            ...
# 268251  2020      3Q      힐스테이트 청계    59    2  동대문구    답십리동  107666.666667
# 268252  2020      3Q      힐스테이트 청계    84    2  동대문구    답십리동  135000.000000
# 268253  2020      3Q       힐스테이트녹번    59    1   은평구     녹번동   88333.333333
# 268254  2020      3Q     힐스테이트송파위례   101    4   송파구     장지동  156000.000000
# 268255  2020      3Q       힐스테이트암사    84    1   강동구     암사동  135000.000000
#
# [268256 rows x 8 columns]

# %%
rent_q=rent1.groupby(['yy','quarter','name','size','age','town','village'])['deposit'].mean()

# %%
rent_q=rent_q.reset_index()

# %%
rent_q
# Out:
#           yy quarter           name      size  age town village        deposit
# 0       2011      1Q        (1-102)   59.9700   23  종로구    명륜3가    3500.000000
# 1       2011      1Q        (248-7)   73.5350   25  강서구     염창동   17500.000000
# 2       2011      1Q        (323-4)  106.5100   15  동작구     상도동   18500.000000
# 3       2011      1Q      (432-904)   52.1100   19   중구     신당동   11000.000000
# 4       2011      1Q  (633-22)로얄팰리스   95.7300   17  강남구     역삼동   32000.000000
# ...      ...     ...            ...       ...  ...  ...     ...            ...
# 292458  2020      4Q        힐스테이트암사   84.9921    1  강동구     암사동   64500.000000
# 292459  2020      4Q        힐스테이트암사   84.9979    1  강동구     암사동   58666.666667
# 292460  2020      4Q            힐캐슬   59.4800    8  금천구     시흥동   22000.000000
# 292461  2020      4Q        힐탑트레져1동  182.8500   17  용산구     한남동  190000.000000
# 292462  2020      4Q        힐탑트레져1동  231.1900   17  용산구     한남동  150000.000000
#
# [292463 rows x 8 columns]

# %%
df=rent_q.merge(sell_q,how='left',on=['yy','quarter','name','size','age','town','village'])
# Out:
# /Users/kang/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py:1097: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,

# %%
df
# Out:
#           yy quarter           name      size  age town village  \
# 0       2011      1Q        (1-102)   59.9700   23  종로구    명륜3가
# 1       2011      1Q        (248-7)   73.5350   25  강서구     염창동
# 2       2011      1Q        (323-4)  106.5100   15  동작구     상도동
# 3       2011      1Q      (432-904)   52.1100   19   중구     신당동
# 4       2011      1Q  (633-22)로얄팰리스   95.7300   17  강남구     역삼동
# ...      ...     ...            ...       ...  ...  ...     ...
# 292458  2020      4Q        힐스테이트암사   84.9921    1  강동구     암사동
# 292459  2020      4Q        힐스테이트암사   84.9979    1  강동구     암사동
# 292460  2020      4Q            힐캐슬   59.4800    8  금천구     시흥동
# 292461  2020      4Q        힐탑트레져1동  182.8500   17  용산구     한남동
# 292462  2020      4Q        힐탑트레져1동  231.1900   17  용산구     한남동
#
#               deposit  price_sold
# 0         3500.000000         NaN
# 1        17500.000000         NaN
# 2        18500.000000         NaN
# 3        11000.000000         NaN
# 4        32000.000000         NaN
# ...               ...         ...
# 292458   64500.000000         NaN
# 292459   58666.666667         NaN
# 292460   22000.000000         NaN
# 292461  190000.000000         NaN
# 292462  150000.000000         NaN
#
# [292463 rows x 9 columns]

# %%
df['deposit'].fillna(0,inplace=True)

# %%
df['gap']=df['price_sold']-df['deposit']

# %%
df
# Out:
#           yy quarter           name      size  age town village  \
# 0       2011      1Q        (1-102)   59.9700   23  종로구    명륜3가
# 1       2011      1Q        (248-7)   73.5350   25  강서구     염창동
# 2       2011      1Q        (323-4)  106.5100   15  동작구     상도동
# 3       2011      1Q      (432-904)   52.1100   19   중구     신당동
# 4       2011      1Q  (633-22)로얄팰리스   95.7300   17  강남구     역삼동
# ...      ...     ...            ...       ...  ...  ...     ...
# 292458  2020      4Q        힐스테이트암사   84.9921    1  강동구     암사동
# 292459  2020      4Q        힐스테이트암사   84.9979    1  강동구     암사동
# 292460  2020      4Q            힐캐슬   59.4800    8  금천구     시흥동
# 292461  2020      4Q        힐탑트레져1동  182.8500   17  용산구     한남동
# 292462  2020      4Q        힐탑트레져1동  231.1900   17  용산구     한남동
#
#               deposit  price_sold  gap
# 0         3500.000000         NaN  NaN
# 1        17500.000000         NaN  NaN
# 2        18500.000000         NaN  NaN
# 3        11000.000000         NaN  NaN
# 4        32000.000000         NaN  NaN
# ...               ...         ...  ...
# 292458   64500.000000         NaN  NaN
# 292459   58666.666667         NaN  NaN
# 292460   22000.000000         NaN  NaN
# 292461  190000.000000         NaN  NaN
# 292462  150000.000000         NaN  NaN
#
# [292463 rows x 10 columns]

# %%
df1=df.loc[(df['deposit']>0)&(df['gap']>0)]

# %%
df1
# Out:
#           yy quarter      name   size  age  town village       deposit  \
# 166     2011      1Q   가락금호아파트   85.0   23   송파구     가락동  30687.500000
# 167     2011      1Q   가락미륭아파트   50.0   34   송파구     가락동  16460.000000
# 652     2011      1Q      고덕시영   43.0   36   강동구     고덕동   5035.294118
# 720     2011      1Q  관악드림(동아)   60.0   17   관악구     봉천동  19812.500000
# 722     2011      1Q  관악드림(동아)  102.0   17   관악구     봉천동  23700.000000
# ...      ...     ...       ...    ...  ...   ...     ...           ...
# 285521  2020      3Q        한신   27.0   33   중랑구     면목동  11000.000000
# 285553  2020      3Q       한신1   27.0   32   노원구     하계동  13130.000000
# 285986  2020      3Q      현대백조   31.0   23   송파구     오금동  18900.000000
# 286032  2020      3Q     현대홈타운  115.0   19   구로구     개봉동  39700.000000
# 286084  2020      3Q   홍제삼성래미안   60.0   19  서대문구     홍제동  34625.000000
#
#           price_sold           gap
# 166     61700.000000  31012.500000
# 167     37000.000000  20540.000000
# 652     52569.230769  47533.936652
# 720     32957.142857  13144.642857
# 722     50000.000000  26300.000000
# ...              ...           ...
# 285521  21900.000000  10900.000000
# 285553  25175.000000  12045.000000
# 285986  50000.000000  31100.000000
# 286032  78500.000000  38800.000000
# 286084  65875.000000  31250.000000
#
# [1571 rows x 10 columns]

# %%
df1.to_excel('/Users/kang/Pandas/Real/gap_quarter.xlsx')

# %%
df1['name'].nunique()
# Out:
# 135
