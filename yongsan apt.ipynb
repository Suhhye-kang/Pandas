# %%
import pandas as pd

# %%
apt_sell=pd.read_excel('/Users/kang/Pandas/Real/apt_sell_all.xlsx')

# %%
apt_sell
# Out:
#         Unnamed: 0   city town village            name  size  price_sold  \
# 0                0  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      160000
# 1                1  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      149500
# 2                2  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      155000
# 3                3  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      157000
# 4                4  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      151500
# ...            ...    ...  ...     ...             ...   ...         ...
# 815967       57229  서울특별시  중랑구     중화동             한신2    84       35700
# 815968       57230  서울특별시  중랑구     중화동             한신2    84       35800
# 815969       57231  서울특별시  중랑구     중화동         한영(104)    68       23250
# 815970       57232  서울특별시  중랑구     중화동           현대휴앤미    82       28000
# 815971       57233  서울특별시  중랑구     중화동           현대휴앤미   100       32500
#
#         floor  year_built    yy  mm  dd zipcode      address
# ...

# %%
yongsan=apt_sell.loc[apt_sell['town']=='용산구']

# %%
yongsan
# Out:
#         Unnamed: 0   city town village     name  size  price_sold  floor  \
# 87689        87689  서울특별시  용산구     갈월동    두리파크빌    69       73200      4
# 87690        87690  서울특별시  용산구     갈월동    두리파크빌    84       90000      1
# 87691        87691  서울특별시  용산구     갈월동    두리파크빌   108      105000      2
# 87692        87692  서울특별시  용산구     도원동    삼성래미안    59       85800     16
# 87693        87693  서울특별시  용산구     도원동    삼성래미안    84       98500     14
# ...            ...    ...  ...     ...      ...   ...         ...    ...
# 811093       52355  서울특별시  용산구     후암동     후암미주    63       44000      3
# 811094       52356  서울특별시  용산구     후암동     후암미주    64       43000      1
# 811095       52357  서울특별시  용산구     후암동     후암미주    64       46700      2
# 811096       52358  서울특별시  용산구     후암동     후암미주    63       44800      2
# 811097       52359  서울특별시  용산구     후암동  힐튼빌리지1차   100       53000      4
#
#         year_built    yy  mm  dd zipcode       address
# ...

# %%
yong=yongsan.groupby(['village','yy'])['price_sold'].mean().to_frame().reset_index()

# %%
yong.pivot(index='yy',columns='village',values='price_sold')
# Out:
# village            갈월동            도원동           동빙고동            동자동  \
# yy
# 2010               NaN   49335.526316   73000.000000   30000.000000
# 2011      50000.000000   50088.524590   98600.000000   28250.000000
# 2012               NaN   47934.864865   80025.500000            NaN
# 2013               NaN   44355.645161   87400.000000   60827.000000
# 2014      43150.000000   47357.368421   91500.000000  110873.298507
# 2015      42000.000000   49920.833333   95600.000000   98040.384615
# 2016      58000.000000   53906.250000  105375.000000   96402.000000
# 2017      67000.000000   62508.536585  105500.000000   90915.000000
# 2018               NaN   71872.463768  126611.111111  122038.775510
# 2019      78066.666667   91334.146341  117000.000000  110881.250000
# 2020     105000.000000  101801.250000  135333.333333  121488.888889
#
# village           문배동            보광동           산천동           서빙고동  \
# yy
# 2010     59080.000000   54083.333333  43433.333333  126937.500000
# ...

# %%
yong.to_excel('/Users/kang/Pandas/Real/yongsan_apt.xlsx')
