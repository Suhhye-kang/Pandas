# %%
import pandas as pd
join=pd.read_excel("/Users/kang/Documents/Github/Pandas/Exercise/lending/join.xlsx")
p2p=pd.read_excel("/Users/kang/Documents/Github/Pandas/Exercise/lending/p2p.xlsx")
p2p_refund=pd.read_excel("/Users/kang/Documents/Github/Pandas/Exercise/lending/p2p_refund.xlsx")
user=pd.read_excel("/Users/kang/Documents/Github/Pandas/Exercise/lending/user.xlsx")

# %%
print(join.info())
print(p2p.info())
print(p2p_refund.info())
print(user.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245396 entries, 0 to 245395
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   경매번호    245396 non-null  object
#  1   경매종류    245396 non-null  object
#  2   참여순서    245396 non-null  int64
#  3   투자자ID   245396 non-null  object
#  4   투자일시    245396 non-null  datetime64[ns]
#  5   투자금액금액  245396 non-null  int64
#  6   투자성사여부  245396 non-null  int64
#  7   입찰이자율   245396 non-null  float64
#  8   오토비딩    245396 non-null  int64
#  9   미투비딩갑   245396 non-null  int64
#  10  미투비딩을   245396 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(3)
# memory usage: 20.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26855 entries, 0 to 26854
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   경매번호          26855 non-null  object
# ...

# %%
print(p2p.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26855 entries, 0 to 26854
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   경매번호          26855 non-null  object
#  1   자금모집시작일       26855 non-null  datetime64[ns]
#  2   자금모집종료일       26855 non-null  datetime64[ns]
#  3   대출자ID         26855 non-null  object
#  4   대출신청금액        26855 non-null  int64
#  5   상환기간          26855 non-null  int64
#  6   대출자 제시 연 이자율  26855 non-null  float64
#  7   매칭방식          26855 non-null  int64
#  8   대출용도          14437 non-null  object
#  9   투자모집 금액       26855 non-null  float64
#  10  투자모집 성공여부     26855 non-null  int64
#  11  투자참여인원수       26855 non-null  int64
#  12  투자모집(오토비드)    26855 non-null  int64
#  13  투자모집(미투비드)    26855 non-null  int64
#  14  최종약정이자율       26855 non-null  float64
#  15  신용보고서         26855 non-null  int64
#  16  소득보고서         26855 non-null  int64
# ...

# %%
p2p.head()
# Out:
#       경매번호             자금모집시작일             자금모집종료일    대출자ID  대출신청금액  상환기간  \
# 0  ADBB538 2007-05-28 05:00:35 2007-06-30 12:00:00  UE799D6     100     3
# 1  A6C8F3E 2007-05-28 05:21:12 2007-09-01 12:00:00  UE799D6     100    12
# 2  A8C32F3 2007-05-28 05:24:10 2007-09-01 12:00:00  UE799D6     200    12
# 3  AAD65CE 2007-05-28 09:44:38 2007-06-01 12:00:00  UB3D977     100     3
# 4  A22DEE1 2007-05-28 09:57:30 2007-06-29 12:00:00  UEA8D32     100     3
#
#    대출자 제시 연 이자율  매칭방식 대출용도  투자모집 금액  ...  주거형태        거주지역     직종  직장세부  혼인상태  \
# 0          25.0     1  NaN      0.0  ...   NaN  서울 서초구 방배동  일반회사원   NaN     0
# 1          29.0     1  NaN      0.0  ...   NaN  서울 서초구 방배동  일반회사원   NaN     0
# 2          29.0     1  NaN      0.0  ...   NaN  서울 서초구 방배동  일반회사원   NaN     0
# 3           7.0     1  NaN      0.0  ...   NaN         NaN    NaN   NaN     0
# 4           6.0     1  NaN      0.0  ...   NaN         NaN    NaN   NaN     0
#
#    동거인수  주거지명의  차량소유  개인회생  Q&A수 게시물 수
# ...

# %%
p2p['year']=p2p['자금모집종료일'].astype(str).str.split('-').str[0]
p2p['month']=p2p['자금모집종료일'].astype(str).str.split('-').str[1]
p2p
# Out:
#           경매번호             자금모집시작일             자금모집종료일    대출자ID  대출신청금액  상환기간  \
# 0      ADBB538 2007-05-28 05:00:35 2007-06-30 12:00:00  UE799D6     100     3
# 1      A6C8F3E 2007-05-28 05:21:12 2007-09-01 12:00:00  UE799D6     100    12
# 2      A8C32F3 2007-05-28 05:24:10 2007-09-01 12:00:00  UE799D6     200    12
# 3      AAD65CE 2007-05-28 09:44:38 2007-06-01 12:00:00  UB3D977     100     3
# 4      A22DEE1 2007-05-28 09:57:30 2007-06-29 12:00:00  UEA8D32     100     3
# ...        ...                 ...                 ...      ...     ...   ...
# 26850  A437E1A 2016-08-01 10:47:47 2016-08-08 12:00:00  U33368B     200    12
# 26851  A169F99 2016-08-01 20:31:29 2016-08-08 12:00:00  UB9235B     200    24
# 26852  AD595CE 2016-08-01 23:19:48 2016-08-10 12:00:00  UC951E9     200    18
# 26853  A6A3E0D 2016-08-02 13:45:31 2016-08-09 12:00:00  UB27D62     200    24
# 26854  A1CCC82 2016-08-02 16:40:37 2016-08-09 12:00:00  UB27D62     200    12
#
# ...

# %%
success=p2p.loc[p2p['투자모집 성공여부']==1]

# %%
success.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2095 entries, 12 to 26849
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   경매번호          2095 non-null   object
#  1   자금모집시작일       2095 non-null   datetime64[ns]
#  2   자금모집종료일       2095 non-null   datetime64[ns]
#  3   대출자ID         2095 non-null   object
#  4   대출신청금액        2095 non-null   int64
#  5   상환기간          2095 non-null   int64
#  6   대출자 제시 연 이자율  2095 non-null   float64
#  7   매칭방식          2095 non-null   int64
#  8   대출용도          1030 non-null   object
#  9   투자모집 금액       2095 non-null   float64
#  10  투자모집 성공여부     2095 non-null   int64
#  11  투자참여인원수       2095 non-null   int64
#  12  투자모집(오토비드)    2095 non-null   int64
#  13  투자모집(미투비드)    2095 non-null   int64
#  14  최종약정이자율       2095 non-null   float64
#  15  신용보고서         2095 non-null   int64
#  16  소득보고서         2095 non-null   int64
# ...

# %%
success['자금모집종료일']
# Out:
# 12      2007-05-31 12:00:00
# 24      2007-06-05 12:00:00
# 46      2007-06-15 12:00:00
# 48      2007-07-07 12:00:00
# 69      2007-07-06 12:00:00
#                 ...
# 26805   2016-07-28 06:03:01
# 26826   2016-08-02 13:00:01
# 26836   2016-07-28 12:00:01
# 26843   2016-07-29 12:00:01
# 26849   2016-08-03 01:21:01
# Name: 자금모집종료일, Length: 2095, dtype: datetime64[ns]

# %%
all1=p2p.groupby(['year','month'])['경매번호'].count()
all=all1.to_frame()
all=all1.reset_index()
all
# Out:
#      year month  경매번호
# 0    2007    05     9
# 1    2007    06    59
# 2    2007    07    48
# 3    2007    08    63
# 4    2007    09    41
# ..    ...   ...   ...
# 107  2016    04    90
# 108  2016    05   100
# 109  2016    06    93
# 110  2016    07    90
# 111  2016    08    35
#
# [112 rows x 3 columns]

# %%
success1=success.groupby(['year','month'])['경매번호'].count()
success_year=success1.to_frame()
success_year=success1.reset_index()
success_year
# Out:
#      year month  경매번호
# 0    2007    05     1
# 1    2007    06     2
# 2    2007    07     6
# 3    2007    08     5
# 4    2007    09     3
# ..    ...   ...   ...
# 107  2016    04     8
# 108  2016    05     6
# 109  2016    06     8
# 110  2016    07    10
# 111  2016    08     2
#
# [112 rows x 3 columns]

# %%
success_year.to_excel('/Users/kang/Documents/Github/Pandas/Exercise/lending/successcount.xlsx')

# %%
all.to_excel('/Users/kang/Documents/Github/Pandas/Exercise/lending/allcount.xlsx')

# %%
pivot_all=all.pivot(index='month',columns='year',values='경매번호')
pivot_all
# Out:
# year    2007   2008   2009    2010   2011   2012   2013   2014   2015   2016
# month
# 01       NaN   64.0  286.0   383.0  371.0  403.0  308.0  140.0   71.0   65.0
# 02       NaN   63.0  318.0   431.0  386.0  492.0  178.0  162.0   91.0   91.0
# 03       NaN   74.0  260.0   437.0  485.0  587.0  203.0  143.0   57.0  101.0
# 04       NaN   86.0  225.0   429.0  478.0  433.0  164.0  109.0   94.0   90.0
# 05       9.0   75.0  186.0   341.0  486.0  423.0  199.0  130.0  104.0  100.0
# 06      59.0   94.0  317.0   366.0  429.0  359.0  201.0   84.0  134.0   93.0
# 07      48.0  188.0  330.0   537.0  413.0  377.0  162.0   92.0   98.0   90.0
# 08      63.0  198.0  473.0  1162.0  376.0  294.0  143.0   55.0   93.0   35.0
# 09      41.0  232.0  443.0   679.0  321.0  268.0  138.0   67.0  106.0    NaN
# 10      72.0  205.0  312.0   438.0  429.0  271.0  131.0   91.0   92.0    NaN
# 11     103.0  202.0  431.0   312.0  514.0  280.0  155.0   97.0   77.0    NaN
# ...

# %%
pivot_all.plot()
